# %%
import pandas as pd
import plotly.express as px

df3_mat = pd.read_csv("plots/student-mat.csv", sep=",")
df3_mat["G3"] = df3_mat["G3"] / 2
df3_mat = df3_mat[["Walc", "Dalc", "G3"]]
df3_por = pd.read_csv("plots/student-por.csv", sep=",")
df3_por["G3"] = df3_por["G3"] / 2
df3_por = df3_por[["Walc", "Dalc", "G3"]]

# %%
df3_mat.head()
# Out:
#    Walc  Dalc   G3  Alcohol
# 0     1     1  3.0      1.0
# 1     1     1  3.0      1.0
# 2     3     2  5.0      2.0
# 3     1     1  7.5      1.0
# 4     2     1  5.0      2.0

# %%
df3_por.head()
# Out:
#    Walc  Dalc   G3  Alcohol
# 0     1     1  5.5      1.0
# 1     1     1  5.5      1.0
# 2     3     2  6.0      2.0
# 3     1     1  7.0      1.0
# 4     2     1  6.5      2.0

# %%
# Alcoholscore berekenen
df3_mat["Alcohol"] = ((df3_mat["Dalc"] + df3_mat["Walc"]) / 2).round()
df3_por["Alcohol"] = ((df3_por["Dalc"] + df3_por["Walc"]) / 2).round()

# Dataset-label toevoegen
mat = df3_mat.copy()
mat["Dataset"] = "Math"

por = df3_por.copy()
por["Dataset"] = "Portuguese"

# Samenvoegen
df_all = pd.concat([mat, por], ignore_index=True)

fig = px.box(
    df_all,
    x="Alcohol",
    y="G3",
    color="Dataset",
    labels={
        "Alcohol": "Average alcohol consumption during the week",
        "G3": "Final grade"
    },
    title="Final grade by average alcohol consumption"
)

fig.update_layout(
    width=1000,
    height=700
)

fig.show()
