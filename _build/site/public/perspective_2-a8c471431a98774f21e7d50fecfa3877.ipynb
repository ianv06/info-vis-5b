# %% [markdown]
# # Balanced Lifestyle

# %% [markdown]
# The balanced lifestyle is about combining studying and leisure activities. In this part we will show how alcohol consumption and gaming impact education performance.

# %% [markdown]
# ## Alcohol Consumption Intensity

# %%
#| class: col-page-right

# %run ../plots/alcohol_consumption_plot1.ipynb

# %% [markdown]
# The datasets student-math and student_portuguese, both part of the alcohol consumption dataset, show a downward trend in the intensity of drinking, shown on the x-axis, and the percentage of students who participates in drinking that often, shown on the y-axis. A high percentage of the students don't drink at all (1 on the x-axis) and a very small percentage drinks everyday or almost every day (4.5-5 on the x-axis). This graph gives a clear illustration of the distribution of drinking intensity among students in these datasets. this bar-chart of the datasets also shows that there is no clear correlation between the course, math or Portuguese, and the percentage of students who participate at drinking at a certain intensity.

# %% [markdown]
# ## Alcohol consumption and final grades

# %%
#| class: col-page-right

# %run ../plots/alcohol_consumption_plot.ipynb

# %% [markdown]
# The datasets student-math and student_portuguese, also show a very subtle trend when it comes to drinking intensity, here also shown on the x-axis, and the final grade at either math or Portuguese, shown on the y-axis. The medians of the final grade related to the alcohol intensity tend to drop slightly when the intensity increases. This is mostly the case at the Portuguese dataset, while we see the median drop from a 6.5 to a 5.0 when the drinking intensity increases from 1 to 5. At the math dataset on the other hand, we see a slight decline of the median from a 5.5 to a 4.0 when the intensity increases from 1 to 3, but after the median increases again to a 5.5 at intensity 5. This can be due to lack of observations for the 4 and 5 intensity in the student math dataset or it can be due to a less powerfull impact on grades when we consider a higher alcohol intensity and maths.

# %% [markdown]
# ## Gaming and response time
#
# The second argument that we bring for the balanced lifestyle perspective is that spending more time gaming will reduce grades, but may improve response times which in turn will improve eduaction performance. This is based on the research of https://link.springer.com/article/10.1186/s12909-020-02416-7, who found that higher response times improve cognitive performance. https://link.springer.com/article/10.1186/s12909-020-02416-7 proved that gaming improves response times. This means that gaming would improve

# %%
#| class: col-page-right

# %run ../plots/gaming_stats_3d.ipynb

# %%
#| class: col-page-right

# %run ../plots/gaming_response_time.ipynb
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_31736\1517859808.py:9
#       6 else:
#       7     df_small = df_filtered.copy()
# ----> 9 fig = px.scatter(
#      10     df_small,
#      11     x="reaction_time_ms",
#      12     y="grades",
#      13     color="grade_category",
#      14     hover_data=[
#      15         "gaming_hours",
#      16         "study_hours",
#      17         "reaction_time_ms",
#      18         "grades",
#      19         "grade_category",
#      20     ],
#      21     labels={
#      22         "reaction_time_ms": "Reaction time (ms) ",
#      23         "grades": "Grade ",
#      24         "gaming_hours": "Gaming hours/week ",
#      25         "grade_category": "Grade category ",
#      26         "study_hours": "Study hours/week ",
#      27     },
#      28     color_discrete_map={
#      29         "fail": "red",
#      30         "sufficient": "orange",
#      31         "good": "green",
#      32     },
#      33     marginal_x="violin",
#      34     trendline="ols",
#      35     title="Grades vs Reaction Time with Gaming Hours and Distributions",
#      36     width=1000,
#      37     height=800,
#      38 )
#      40 # Make points readable
#      41 fig.update_traces(marker=dict(size=12, opacity=0.7, line=dict(width=0.5, color="black")))
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:69, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, subtitle, template, width, height)
#      14 def scatter(
#      15     data_frame=None,
#      16     x=None,
#    (...)
#      63     height=None,
#      64 ) -> go.Figure:
#      65     """
#      66     In a scatter plot, each row of `data_frame` is represented by a symbol
#      67     mark in 2D space.
#      68     """
# ---> 69     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:2703, in make_figure(args, constructor, trace_patch, layout_patch)
#    2700     elif args["ecdfnorm"] == "percent":
#    2701         group = group.with_columns((nw.col(var) / group_sum) * 100.0)
# -> 2703 patch, fit_results = make_trace_kwargs(
#    2704     args, trace_spec, group, mapping_labels.copy(), sizeref
#    2705 )
#    2706 trace.update(patch)
#    2707 if fit_results is not None:
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:430, in make_trace_kwargs(args, trace_spec, trace_data, mapping_labels, sizeref)
#     427     trace_patch["x"] = trace_patch["x"].to_numpy()
#     429 trendline_function = trendline_functions[attr_value]
# --> 430 y_out, hover_header, fit_results = trendline_function(
#     431     args["trendline_options"],
#     432     sorted_trace_data.get_column(args["x"]),  # narwhals series
#     433     x.to_numpy(),  # numpy array
#     434     y.to_numpy(),  # numpy array
#     435     args["x"],
#     436     args["y"],
#     437     non_missing.to_numpy(),  # numpy array
#     438 )
#     439 assert len(y_out) == len(trace_patch["x"]), (
#     440     "missing-data-handling failure in trendline code"
#     441 )
#     442 trace_patch["y"] = y_out
#
# File ~\anaconda3\Lib\site-packages\plotly\express\trendline_functions\__init__.py:42, in ols(trendline_options, x_raw, x, y, x_label, y_label, non_missing)
#      36     if k not in valid_options:
#      37         raise ValueError(
#      38             "OLS trendline_options keys must be one of [%s] but got '%s'"
#      39             % (", ".join(valid_options), k)
#      40         )
# ---> 42 import statsmodels.api as sm
#      44 add_constant = trendline_options.get("add_constant", True)
#      45 log_x = trendline_options.get("log_x", False)
#
# File ~\anaconda3\Lib\site-packages\statsmodels\api.py:76
#       1 __all__ = [
#       2     "BayesGaussMI",
#       3     "BinomialBayesMixedGLM",
#    (...)
#      72     "__version_info__"
#      73 ]
# ---> 76 from . import datasets, distributions, iolib, regression, robust, tools
#      77 from .__init__ import test
#      78 from statsmodels._version import (
#      79     version as __version__, version_tuple as __version_info__
#      80 )
#
# File ~\anaconda3\Lib\site-packages\statsmodels\distributions\__init__.py:7
#       2 from .empirical_distribution import (
#       3     ECDF, ECDFDiscrete, monotone_fn_inverter, StepFunction
#       4     )
#       5 from .edgeworth import ExpandedNormal
# ----> 7 from .discrete import (
#       8     genpoisson_p, zipoisson, zigenpoisson, zinegbin,
#       9     )
#      11 __all__ = [
#      12     'ECDF',
#      13     'ECDFDiscrete',
#    (...)
#      21     'zipoisson'
#      22     ]
#      24 test = PytestTester()
#
# File ~\anaconda3\Lib\site-packages\statsmodels\distributions\discrete.py:5
#       3 from scipy.stats import rv_discrete, poisson, nbinom
#       4 from scipy.special import gammaln
# ----> 5 from scipy._lib._util import _lazywhere
#       7 from statsmodels.base.model import GenericLikelihoodModel
#      10 class genpoisson_p_gen(rv_discrete):
#
# ImportError: cannot import name '_lazywhere' from 'scipy._lib._util' (C:\Users\ianva\anaconda3\Lib\site-packages\scipy\_lib\_util.py)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 #| class: col-page-right
# ----> 3 get_ipython().run_line_magic('run', '../plots/gaming_response_time.ipynb')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:741, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     739     with preserve_keys(self.shell.user_ns, '__file__'):
#     740         self.shell.user_ns['__file__'] = filename
# --> 741         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     742     return
#     744 # Control the response to exit() calls made by the script being run
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_31736\1517859808.py:9
#       6 else:
#       7     df_small = df_filtered.copy()
# ----> 9 fig = px.scatter(
#      10     df_small,
#      11     x="reaction_time_ms",
#      12     y="grades",
#      13     color="grade_category",
#      14     hover_data=[
#      15         "gaming_hours",
#      16         "study_hours",
#      17         "reaction_time_ms",
#      18         "grades",
#      19         "grade_category",
#      20     ],
#      21     labels={
#      22         "reaction_time_ms": "Reaction time (ms) ",
#      23         "grades": "Grade ",
#      24         "gaming_hours": "Gaming hours/week ",
#      25         "grade_category": "Grade category ",
#      26         "study_hours": "Study hours/week ",
#      27     },
#      28     color_discrete_map={
#      29         "fail": "red",
#      30         "sufficient": "orange",
#      31         "good": "green",
#      32     },
#      33     marginal_x="violin",
#      34     trendline="ols",
#      35     title="Grades vs Reaction Time with Gaming Hours and Distributions",
#      36     width=1000,
#      37     height=800,
#      38 )
#      40 # Make points readable
#      41 fig.update_traces(marker=dict(size=12, opacity=0.7, line=dict(width=0.5, color="black")))
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:69, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, subtitle, template, width, height)
#      14 def scatter(
#      15     data_frame=None,
#      16     x=None,
#    (...)
#      63     height=None,
#      64 ) -> go.Figure:
#      65     """
#      66     In a scatter plot, each row of `data_frame` is represented by a symbol
#      67     mark in 2D space.
#      68     """
# ---> 69     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:2703, in make_figure(args, constructor, trace_patch, layout_patch)
#    2700     elif args["ecdfnorm"] == "percent":
#    2701         group = group.with_columns((nw.col(var) / group_sum) * 100.0)
# -> 2703 patch, fit_results = make_trace_kwargs(
#    2704     args, trace_spec, group, mapping_labels.copy(), sizeref
#    2705 )
#    2706 trace.update(patch)
#    2707 if fit_results is not None:
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:430, in make_trace_kwargs(args, trace_spec, trace_data, mapping_labels, sizeref)
#     427     trace_patch["x"] = trace_patch["x"].to_numpy()
#     429 trendline_function = trendline_functions[attr_value]
# --> 430 y_out, hover_header, fit_results = trendline_function(
#     431     args["trendline_options"],
#     432     sorted_trace_data.get_column(args["x"]),  # narwhals series
#     433     x.to_numpy(),  # numpy array
#     434     y.to_numpy(),  # numpy array
#     435     args["x"],
#     436     args["y"],
#     437     non_missing.to_numpy(),  # numpy array
#     438 )
#     439 assert len(y_out) == len(trace_patch["x"]), (
#     440     "missing-data-handling failure in trendline code"
#     441 )
#     442 trace_patch["y"] = y_out
#
# File ~\anaconda3\Lib\site-packages\plotly\express\trendline_functions\__init__.py:42, in ols(trendline_options, x_raw, x, y, x_label, y_label, non_missing)
#      36     if k not in valid_options:
#      37         raise ValueError(
#      38             "OLS trendline_options keys must be one of [%s] but got '%s'"
#      39             % (", ".join(valid_options), k)
#      40         )
# ---> 42 import statsmodels.api as sm
#      44 add_constant = trendline_options.get("add_constant", True)
#      45 log_x = trendline_options.get("log_x", False)
#
# File ~\anaconda3\Lib\site-packages\statsmodels\api.py:76
#       1 __all__ = [
#       2     "BayesGaussMI",
#       3     "BinomialBayesMixedGLM",
#    (...)
#      72     "__version_info__"
#      73 ]
# ---> 76 from . import datasets, distributions, iolib, regression, robust, tools
#      77 from .__init__ import test
#      78 from statsmodels._version import (
#      79     version as __version__, version_tuple as __version_info__
#      80 )
#
# File ~\anaconda3\Lib\site-packages\statsmodels\distributions\__init__.py:7
#       2 from .empirical_distribution import (
#       3     ECDF, ECDFDiscrete, monotone_fn_inverter, StepFunction
#       4     )
#       5 from .edgeworth import ExpandedNormal
# ----> 7 from .discrete import (
#       8     genpoisson_p, zipoisson, zigenpoisson, zinegbin,
#       9     )
#      11 __all__ = [
#      12     'ECDF',
#      13     'ECDFDiscrete',
#    (...)
#      21     'zipoisson'
#      22     ]
#      24 test = PytestTester()
#
# File ~\anaconda3\Lib\site-packages\statsmodels\distributions\discrete.py:5
#       3 from scipy.stats import rv_discrete, poisson, nbinom
#       4 from scipy.special import gammaln
# ----> 5 from scipy._lib._util import _lazywhere
#       7 from statsmodels.base.model import GenericLikelihoodModel
#      10 class genpoisson_p_gen(rv_discrete):
#
# ImportError: cannot import name '_lazywhere' from 'scipy._lib._util' (C:\Users\ianva\anaconda3\Lib\site-packages\scipy\_lib\_util.py)

# %% [markdown]
# The two graphs suggest that reaction time does not appear to have a strong influence on grades, because the data points do not show a clear or consistent pattern. In contrast, the amount of gaming seems to be more strongly related to grades, since the trend in that graph is more noticeable. Taken together, this means our results do not support the idea that reaction time is an important predictor of grades in this dataset. That is interesting because it seems to contradict https://link.springer.com/article/10.1186/s12909-020-02416-7, who reports a different relationship between these factors and academic performance. The paper suggests that reaction time has a positive impact on educational performance because faster reaction times may reflect quicker information processing, better attentional control, or more efficient cognitive functioning, which can support learning and test performance.
