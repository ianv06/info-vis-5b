# %% [markdown]
# # Balanced Lifestyle

# %% [markdown]
# The balanced lifestyle is about combining studying and leisure activities. In this part we will show how alcohol consumption and gaming impact education performance.

# %% [markdown]
# ## Alcohol Consumption Intensity
# The first argument that we use for the balanced lifestyle perspective is that alcohol consumption has a negative impact on the final grade of a student, this argument is based on the paper of https://www.sciencedirect.com/science/article/abs/pii/S0047272710001143?vi The paper found that increased alcohol consumption caused significant reductions in student achievement, particularly among high-performing students.

# %%
#| class: col-page-right

# %run ../plots/alcohol_consumption_plot1.ipynb

# %% [markdown]
# *Figure 5: Distribution of alcohol consumption*

# %% [markdown]
# ## Alcohol consumption and final grades

# %%
#| class: col-page-right
# %run ../plots/alcohol_consumption_plot.ipynb

# %% [markdown]
# *Figure 6: Final grade by average alcohol consumption*

# %% [markdown]
# The second graph shows a weak negative correlation between final grades, average alcohol consumption, and course. A slight decline in performance can be observed as alcohol consumption increases, with a somewhat stronger effect for Portuguese than for Mathematics. The first graph also shows that alcohol consumption levels between 4 and 5 are underrepresented, which may influence these findings. Overall, our results partially support the findings of https://www.sciencedirect.com/science/article/abs/pii/S0047272710001143?vi, who also found that increased alcohol consumption was associated with lower grades, although the relationship in our data appears less pronounced.

# %% [markdown]
# ## Gaming and response time
#
# The second argument that we bring for the balanced lifestyle perspective is that spending more time gaming will reduce grades, but may improve response times which in turn will improve eduaction performance. This is based on the research of https://link.springer.com/article/10.1186/s12909-020-02416-7, who found that higher response times improve cognitive performance. https://link.springer.com/article/10.1186/s12909-020-02416-7 proved that gaming improves response times. This means that gaming would improve

# %%
#| class: col-page-right

# %run ../plots/gaming_stats_3d.ipynb

# %% [markdown]
# *Figure 7: Reaction time vs Grades vs Gaming Hours*

# %%
#| class: col-page-right
# %run ../plots/gaming_response_time.ipynb
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_28400\1625713202.py:1
# ----> 1 df = pd.read_csv("Gaming_Academic_Performance.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)
# ...

# %% [markdown]
# The two figures suggest that reaction time does not appear to have a strong influence on grades, because the data points do not show a clear or consistent pattern. In contrast, the amount of gaming seems to be more strongly related to grades, since the trend in that graph is more noticeable. Taken together, this means our results do not support the idea that reaction time is an important predictor of grades in this dataset. That is interesting because it seems to contradict https://link.springer.com/article/10.1186/s12909-020-02416-7, who reports a different relationship between these factors and academic performance. The paper suggests that reaction time has a positive impact on educational performance because faster reaction times may reflect quicker information processing, better attentional control, or more efficient cognitive functioning, which can support learning and test performance.
