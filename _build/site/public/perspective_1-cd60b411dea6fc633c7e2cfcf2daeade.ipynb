# %% [markdown]
# # Strict Lifestyle

# %%
Argument 1: Having a strict lifestyle (e.g. only focusing on studying and not participating in leisure activities) improves students’ academic performance.

# %%
1. Substantiation 1: Students spending more time studying tend to achieve higher academic performance (Study time)

# %%
# %run plots/study_time_plot.ipynb
