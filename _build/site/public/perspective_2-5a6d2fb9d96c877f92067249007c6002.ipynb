# %% [markdown]
# # Balanced Lifestyle

# %% [markdown]
# The balanced lifestyle is about combining studying and leisure activities.

# %% [markdown]
# ## Argument 1
# The first argument is that gaming improves reaction time, which improves education performance. https://link.springer.com/article/10.1186/s12909-020-02416-7

# %% [markdown]
# ## Argument 2
