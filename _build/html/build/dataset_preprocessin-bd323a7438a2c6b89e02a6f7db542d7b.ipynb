# %% [markdown]
# # Dataset and Preprocessing
#
# One of our first activities as a team was to find datasets about topics that interested us. After all finding a few datasets, we found that we had multiple datasets about education and how it was impacted by other factors. Eventually, we made a selection of three different datasets
