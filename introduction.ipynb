# %% [markdown]
# # Introduction

# %% [markdown]
# What factors help improve academic performance has always been a crucial question of generations of students and also researchers in the education field (e.g. https://doi.org/10.1001/jamapediatrics.2019.3176, https://doi.org/10.1136/bjsports-2017-098136, https://doi.org/10.1007/s10648-020-09585-3).
#
# In some perspectives, a successful study method is investing most of study time per day without any distraction from social activities, gaming or entertainment. Previous study shows that study habits, skills, and attitudes can predict student academic performance, meaning that having serious learning behaviors for everyday plays an important role in grades (https://doi.org/10.1111/j.1745-6924.2008.00089.x).
#
# However, nowadays, student life is not just studying. They also spent time socializing and participating in other physical or extracurricular activities. Studying in a strict way might not be the most effective method to acquire high scores. https://doi.org/10.3390/ijerph17165972 found that sports participation may benefit students’ academic achievement. Besides, according to https://doi.org/10.1002/pits.10136 findings, participating in extracurricular activities in a structured way can also enhance school performance of students.
#
# Therefore, this data story aims to investigate whether living chill or living strictly would be more beneficial to students’ study, and the role of external variables such as stress level and parental supervision in the relationship between type of lifestyle and academic performance. Four datasets shared on Kaggle were used to structure the story: “Student lifestyle dataset” (https://doi.org/10.1002/pits.10136
# https://www.kaggle.com/datasets/steve1215rogg/student-lifestyle-dataset), “Gaming vs Academic Performance” (https://www.kaggle.com/datasets/aiexplorer77/gaming-vs-academic-performance), “Student Alcohol Consumption” (https://www.kaggle.com/datasets/uciml/student-alcohol-consumption) and “Student Habits vs Academic Performance” (https://www.kaggle.com/datasets/jayaantanaath/student-habits-vs-academic-performance).

# %% [markdown]
# # Reference

# %% [markdown]
# Adelantado-Renau, M., Moliner-Urdiales, D., Cavero-Redondo, I., Beltran-Valls, M. R., Martínez-Vizcaíno, V., & Álvarez-Bueno, C. (2019). Association Between Screen Media Use and Academic Performance Among Children and Adolescents: A Systematic Review and Meta-analysis. JAMA Pediatrics, 173(11), 1058–1067. https://doi.org/10.1001/jamapediatrics.2019.3176
#
# AIExplorer77. (n.d.). Gaming vs academic performance [Data set]. Kaggle. https://www.kaggle.com/datasets/aiexplorer77/gaming-vs-academic-performance
#
# Barbosa, A., Whiting, S., Simmonds, P., Scotini Moreno, R., Mendes, R., & Breda, J. (2020). Physical Activity and Academic Achievement: An Umbrella Review. International Journal of Environmental Research and Public Health, 17(16), 5972. https://doi.org/10.3390/ijerph17165972
#
# Camacho-Morles, J., Slemp, G. R., Pekrun, R., Loderer, K., Hou, H., & Oades, L. G. (2021). Activity achievement emotions and academic performance: A meta-analysis. Educational Psychology Review, 33(3), 1051–1095. https://doi.org/10.1007/s10648-020-09585-3
#
# Cortez, P., & Silva, A. (2008). Student alcohol consumption [Data set]. UCI Machine Learning Repository. https://archive.ics.uci.edu/ml/datasets/Student+Alcohol+Consumption
#
# Gilman, R., Meyers, J., & Perez, L. (2004). Structured extracurricular activities among adolescents: Findings and implications for school psychologists. Psychology in the Schools, 41(1), 31–41. https://doi.org/10.1002/pits.10136
#
# Jayaantanaath. (n.d.). Student habits vs academic performance [Data set]. Kaggle. https://www.kaggle.com/datasets/jayaantanaath/student-habits-vs-academic-performance
#
# Kumar, S. (2025). Student lifestyle dataset [Data set]. Kaggle. https://www.kaggle.com/datasets/steve1215rogg/student-lifestyle-dataset
#
# Richardson, M., Abraham, C., & Bond, R. (2012). Psychological Correlates of University Students’ Academic Performance: A Systematic Review and Meta-Analysis. Psychological Bulletin, 138(2), 353–387. https://doi.org/10.1037/a0026838
#
# Singh, A. S., Saliasi, E., van den Berg, V., Uijtdewilligen, L., de Groot, R. H. M., Jolles, J., Andersen, L. B., Bailey, R., Chang, Y.-K., Diamond, A., Ericsson, I., Etnier, J. L., Fedewa, A. L., Hillman, C. H., McMorris, T., Pesce, C., Pühse, U., Tomporowski, P. D., & Chinapaw, M. J. M. (2019). Effects of physical activity interventions on cognitive and academic performance in children and adolescents: a novel combination of a systematic review and recommendations from an expert panel. British Journal of Sports Medicine, 53(10), 640–647. https://doi.org/10.1136/bjsports-2017-098136
